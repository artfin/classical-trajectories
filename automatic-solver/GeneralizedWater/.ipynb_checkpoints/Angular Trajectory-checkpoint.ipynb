# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.plotly as py
import numpy as np
import json

# loading jx,jy,jz values
with open('angular_trajectory.dat', mode = 'r') as inputfile:
    data = json.load(inputfile)

theta = np.linspace(0, 2*np.pi, 100)
phi = np.linspace(0, np.pi, 100)
J = 25.
x = J * np.outer(np.cos(theta), np.sin(phi))
y = J * np.outer(np.sin(theta), np.sin(phi))
z = J * np.outer(np.ones(100), np.cos(phi))
    
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection = '3d')
ax.plot_surface(x,y,z, alpha = 0.1)
ax.plot(data['jx'], data['jy'], data['jz'], color = 'g')
plt.draw()
plt.show()
